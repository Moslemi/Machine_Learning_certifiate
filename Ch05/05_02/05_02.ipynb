# %% [markdown]
# ![title](Header__0005_5.png "Header")
# ___
# # Chapter 5 - Outlier Analysis
# ## Segment 2 - Multivariate analysis for outlier detection

# %%
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %% [markdown]
# ### Visually inspecting boxplots

# %%
df = pd.read_csv(
    filepath_or_buffer='iris.data.csv', #'C:/Users/Lillian Pierson/Desktop/Exercise Files/Ch05/05_02/iris.data.csv',
    header=None,
    sep=',')

df.columns=['Sepal Length','Sepal Width','Petal Length','Petal Width', 'Species']
data = df.iloc[:,0:4].values
target = df.iloc[:,4].values
df[:5]

sb.boxplot(x='Species', y='Sepal Length', data=df, palette='hls') # palette :color style

# %% [markdown]
# ### Looking at the scatterplot matrix

# %%
sb.pairplot(df, hue='Species', palette='hls')#Variable in data to map plot aspects to different colors.(main_variable)
