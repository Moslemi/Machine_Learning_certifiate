# %% [markdown]
# ![title](Header__0008_2.png "Header")
# ___
# # Chapter 2 - Data Visualization
# ## Segment 4 - Creating labels and annotations

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 8,4
sb.set_style('whitegrid')

# %% [markdown]
# ### Labeling plot features
# #### The functional method

# %%
x = range(1,10)
y = [1,2,3,4,0.5,4,3,2,1]
plt.bar(x,y)

plt.xlabel('your x-axis label')
plt.ylabel('your y-axis label')
# Out:
# Text(0, 0.5, 'your y-axis label')

# %%
z = [1 , 2, 3, 4, 0.5]
veh_type = ['bicycle', 'motorbike','car', 'van', 'stroller']
plt.pie(z, labels= veh_type)
plt.show()

# %% [markdown]
# #### The object-oriented method

# %%
address =   'mtcars.csv'#'C:/Users/Lillian Pierson/Desktop/Exercise Files/Ch02/02_04/mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars.mpg

fig = plt.figure()
ax = fig.add_axes([.1, .1, 1, 1])

mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')  # specify label, rotarion, and fontize  
ax.set_title('Miles per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')
# Out:
# Text(0, 0.5, 'miles/gal')

# %% [markdown]
# ### Adding a legend to your plot
# #### The functional method

# %%
plt.pie(z)
plt.legend(veh_type, loc='best')   # specify the place of legend and their lables
plt.show()

# %% [markdown]
# #### The object-oriented method

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()

ax.set_xticks(range(32))

ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per Gallon of Cars in mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')

ax.legend(loc='best')

# %% [markdown]
# ### Annotating your plot

# %%
mpg.max()
# Out:
# 33.9

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()
ax.set_title('Miles per Gallon of Cars in mtcars')
ax.set_ylabel('miles/gal')

ax.set_ylim([0,45])
                                                                   # using ax.annotate for creating annotation 
ax.annotate('Toyota Corolla', xy=(19,33.9), xytext = (23,35),      # xy is the location of maximum point, x =19 : 
           arrowprops=dict(facecolor='black', shrink=0.05))        # y = mpg.max()
                                                                   # xytext : is the location of text for xy
                                                                   #  here xytest is Toyota Crolla
# Out:
# Text(23, 35, 'Toyota Corolla')
